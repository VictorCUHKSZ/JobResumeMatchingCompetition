# %%
import pandas as pd

# %%
data_train_df = pd.read_csv('train.csv')
data_train_df.head(10)
# Out:
#    id            level_1  level_2           level_3  \
# 0   0  工业/危化品类（现场）—2016版  （二）电气安全  6、移动用电产品、电动工具及照明
# 1   1  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 2   2  工业/危化品类（现场）—2016版  （一）消防检查            2、防火检查
# 3   3  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 4   4  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 5   5  工业/危化品类（现场）—2016版  （一）消防检查            2、防火检查
# 6   6  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 7   7  工业/危化品类（现场）—2016版  （一）消防检查            1、防火巡查
# 8   8  工业/危化品类（现场）—2016版  （一）消防检查            2、防火检查
# 9   9  工业/危化品类（现场）—2016版  （四）作业环境            1、作业通道
#
#                                              level_4  \
# 0  1、移动使用的用电产品和I类电动工具的绝缘线，必须采用三芯(单相)或四芯(三相)多股铜芯橡套软线。
# 1                           3、消防设施、器材和消防安全标志是否在位、完整；
# 2                           6、重点工种人员以及其他员工消防知识的掌握情况；
# 3                           3、消防设施、器材和消防安全标志是否在位、完整；
# 4                  4、常闭式防火门是否处于关闭状态，防火卷帘下是否堆放物品影响使用；
# 5           8、易燃易爆危险物品和场所防火防爆措施的落实情况以及其他重要物资的防火安全情况；
# ...

# %%
person_df = pd.read_csv(r"trainset\person.csv")
person_df.head(10)
# Out:
#    PERSON_ID GENDER  WORK_YEARS HIGHEST_EDU      MAJOR  AGE LAST_POSITION  \
# 0      33291      男          15          大专    计算机应用技术   37   网络管理/信息安全管理
# 1    2985277      男          12          大专    计算机应用技术   35    *公关/营销/业务类
# 2    2982066      女          10          大专  金融学（含保险学）   32           出纳
# 3    3010866      男          10          中专      物理电子学   34     营销代表/销售顾问
# 4  316816964      女          15          中专      学前教育学   34  小学教育/幼儿教育/保育
# 5    6146769      男          17        大学本科     公共行政管理   39          行政管理
# 6    2999986      女          15          大专  财政学（含税收学）   38          财务管理
# 7    4520228      女          14          大专       经贸英语   33      项目总监/负责人
# 8    6146768      男          18   高中（职高、技校）       财务管理   37     *物流/交通运输类
# 9    2980989      男          10          大专        NaN   31          产品开发
#
#   LAST_INDUSTRY CURR_LOC                          LANGUAGE_REMARK  \
# 0           NaN      深圳市  普通话：精通  广东话：精通******语：听：良好，说：良好，读：良好，写：
# ...

# %%
person_df.tail(10)
# Out:
#        PERSON_ID GENDER  WORK_YEARS HIGHEST_EDU      MAJOR  AGE  \
# 54769    4887740      女          12        大学本科        NaN   34
# 54770    5659054      男          10          大专  电子信息科学与技术   29
# 54771    5886220      男           7        大学本科        NaN   29
# 54772    1915470      女          14        大学本科       企业管理   36
# 54773    6179149      男          18        大学本科  机械制造及其自动化   37
# 54774    4546928      男          14          大专        NaN   47
# 54775    6261517      男          26        大学本科       财务管理   48
# 54776    5642172      男          13          大专        NaN   32
# 54777    5433634      男          13       博士研究生    管理科学与工程   39
# 54778    4924201      男          26       硕士研究生  工商管理(MBA)   48
#
#              LAST_POSITION LAST_INDUSTRY CURR_LOC  \
# 54769               人力资源管理          通讯行业      深圳市
# 54770         智能大厦/综合布线/弱电           NaN      深圳市
# 54771                 机械设计        零售百货行业      龙岗区
# 54772                 运营管理          电子行业      深圳市
# ...

# %%
personCV_df = pd.read_csv(r"trainset\person_cv.csv")
personCV_df.head(10)
# Out:
#    PERSON_ID                                       SELF_COMMENT  \
# 0    2985277                                        面谈或电话，并提供资料
# 1    4736088  工作方面：积极主动，责任心较强，有团队协作精神；学习方面：谦虚好学，积极进取；心理方面：乐观...
# 2    3016588  本人性格开朗,品行端正,对环境适应能力强，做事踏实，细心，工作认真负责，工作责任心强，有上进...
# 3    2981299  在过去一段时间的社会实践及工作经历磨练了的求实作风、上进之心和坚忍不拔的个性。以本人良好的敬...
# 4    2983790  １：本人为全国注册监理工程师，职称为高级工程师，先后从事过建筑施工、房地产开发、以及监理行业...
# 5    2971157     本人组织协调能力强，沟通能力强，具有较强的领导能力,能组织一只强有力的高效工作团队，愿...
# 6      24295  本人工作9年以来，一直从事制造企业会计、财务管理工作，精于制造企业会计核算、成本控制、全面预...
# 7      26868  1.具备良好的语言、文字表达能力；2.诚信正直，勤勉尽责，工作积极主动;3.具有良好的团队精...
# 8      30203  本人工作认真负责，刻苦钻研，在单位多次受到单位领导的表扬和肯定。本人能对电力工程（如外线、高...
# 9    1719559                              做事脚踏实地工作有创新精神对问题有挑战精神
#
#               POSITION LOCATION    INDUSTRY  AVAILABLE_IN_DAYS         REMARK
# 0                  导游       深圳市    餐饮旅游娱乐行业                NaN            NaN
# 1                 *机械类      深圳市         NaN               14.0            NaN
# ...

# %%
personCV_df.iloc[1, 1]
# Out:
# '工作方面：积极主动，责任心较强，有团队协作精神；学习方面：谦虚好学，积极进取；心理方面：乐观开朗，能承受压力与挫折；'

# %%
person_df.iloc[1, 9]
# Out:
# '普通话：精通  广东话：精通************语：听：精通，说：精通，读'
